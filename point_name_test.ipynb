# %%
import pandas as pd

#import data
temp_point_data = pd.read_csv(r"/home/engineering/Documents/PdM/data/temp_data/point_names.csv", low_memory=False)
temp_point_df = pd.DataFrame(temp_point_data)

# %%
filepath = "/home/engineering/Documents/PdM/data/temp_data/point_names.csv"

test_import = pd.read_csv(filepath, low_memory=False)
test_df = pd.DataFrame(test_import)
test_df.shape[0]
# Out:
# 38

# %%
temp_point_df
# Out:
#    Point_Name                      Tag    TechID
# 0     Point_1       M630.FZ-1W26A.TEMP     1W26A
# 1     Point_2       M630.FZ-1W26B.TEMP     1W26B
# 2     Point_3       M630.FZ-1W26C.TEMP     1W26C
# 3     Point_4       M630.FZ-1W26D.TEMP     1W26D
# 4     Point_5       M630.FZ-1W17A.TEMP     1W17A
# 5     Point_6        M630.CR-1W26.TEMP      1W26
# 6     Point_7        M630.CR-1W27.TEMP      1W27
# 7     Point_8        M630.CR-1W28.TEMP      1W28
# 8     Point_9        M630.CR-1W17.TEMP      1W17
# 9    Point_10     M633.CR1S17.TEMP.RTD      1S17
# 10   Point_11     M633.CR1S20.TEMP.RTD      1S20
# 11   Point_12     M633.CR1P36.TEMP.RTD      1P36
# 12   Point_13     M633.CR1W09.TEMP.RTD      1W09
# 13   Point_14     M633.CR1W10.TEMP.RTD      1W10
# 14   Point_15         M633.RM4L04.TEMP      4L04
# 15   Point_16        M633.RM4L11A.TEMP     4L11A
# 16   Point_17        M633.RM4L26A.TEMP     4L26A
# 17   Point_18     M633.CR6P24.RTD.TEMP      6P24
# 18   Point_19        M633.CR-6P61.TEMP      6P61
# 19   Point_20  M636.WH.ENVIRO.ER1.TEMP       ER1
# 20   Point_21  M636.WH.ENVIRO.CR2.TEMP       ER2
# 21   Point_22  M636.WH.ENVIRO.CR3.TEMP       ER3
# 22   Point_23  M636.WH.ENVIRO.CR4.TEMP       ER4
# 23   Point_24  M636.WH.ENVIRO.CR5.TEMP       ER5
# 24   Point_25  M636.WH.ENVIRO.CR6.TEMP       ER6
# 25   Point_26  M636.QCL.CR-601001.TEMP  CR601001
# 26   Point_27  M636.INC.CR-601002.TEMP  CR601002
# 27   Point_28  M636.QCL.CR-601003.TEMP  CR601003
# 28   Point_29  M636.INC.CR-601005.TEMP  CR601005
# 29   Point_30       M660.QC.ER-12.TEMP      ER12
# 30   Point_31       M660.QC.ER-13.TEMP      ER13
# 31   Point_32    M660.WH.ER.S105A.TEMP     S105A
# 32   Point_33    M660.WH.ER.S105B.TEMP     S105B
# 33   Point_34    M660.WH.ER.S105C.TEMP     S105C
# 34   Point_35    M660.WH.CR.S101A.TEMP     S101A
# 35   Point_36    M660.WH.CR.S101B.TEMP     S101B
# 36   Point_37    M660.WH.CR.S101C.TEMP     S101C
# 37   Point_38    M660.WH.CR.S101D.TEMP     S101D

# %%
temp_data = pd.read_csv(r"/home/engineering/Documents/PdM/data/temp_data/temp_data_2026_01_19.csv", low_memory=False)
temp_df = pd.DataFrame(temp_data)
temp_df
# Out:
#             Date      Time  Point_1  Point_2  Point_3  Point_4  Point_5  \
# 0       1/1/2026  00:00:00   -41.12   -41.41   -40.68   -40.44   -20.63
# 1       1/1/2026  00:01:00   -41.12   -41.41   -40.68   -40.44   -20.63
# 2       1/1/2026  00:02:00   -41.12   -41.41   -40.68   -40.44   -20.63
# 3       1/1/2026  00:03:00   -41.12   -41.41   -40.68   -40.44   -20.63
# 4       1/1/2026  00:04:00   -41.12   -41.41   -40.68   -40.44   -20.63
# ...          ...       ...      ...      ...      ...      ...      ...
# 26411  1/19/2026  08:11:00   -41.37   -41.39   -40.73   -40.41   -20.84
# 26412  1/19/2026  08:12:00   -41.37   -41.39   -40.73   -40.41   -20.84
# 26413  1/19/2026  08:13:00   -41.37   -41.39   -40.73   -40.41   -20.84
# 26414  1/19/2026  08:14:00   -41.37   -41.39   -40.73   -40.41   -20.84
# 26415  1/19/2026  08:15:00   -41.37   -41.39   -40.45   -40.42   -20.84
#
#        Point_6  Point_7  Point_8  ...  Point_29  Point_30  Point_31  Point_32  \
# 0         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# 1         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# 2         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# 3         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# 4         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# ...        ...      ...      ...  ...       ...       ...       ...       ...
# 26411     4.51     5.04     5.62  ...      5.09      5.06      4.86      4.76
# 26412     4.51     5.04     5.62  ...      5.09      5.06      4.86      4.76
# 26413     4.51     5.04     5.62  ...      5.09      5.06      4.86      4.76
# 26414     4.51     5.04     5.62  ...      5.09      5.06      4.86      4.76
# 26415     4.51     5.01     5.63  ...      5.09      5.09      5.58      4.77
#
#        Point_33  Point_34  Point_35 Point_36 Point_37  Point_38
# 0        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# 1        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# 2        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# 3        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# 4        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# ...         ...       ...       ...      ...      ...       ...
# 26411    -21.40    -39.07      4.99   -39.79     5.18    -40.04
# 26412    -21.40    -39.07      4.99   -39.79     5.18    -40.04
# 26413    -21.40    -39.07      4.99   -39.79     5.18    -40.04
# 26414    -21.40    -39.07      4.99   -39.79     5.18    -41.04
# 26415    -20.64    -40.14      5.00   -39.08     5.19    -41.64
#
# [26416 rows x 40 columns]

# %%
test_df = temp_df.copy()
test_df
# Out:
#             Date      Time  Point_1  Point_2  Point_3  Point_4  Point_5  \
# 0       1/1/2026  00:00:00   -41.12   -41.41   -40.68   -40.44   -20.63
# 1       1/1/2026  00:01:00   -41.12   -41.41   -40.68   -40.44   -20.63
# 2       1/1/2026  00:02:00   -41.12   -41.41   -40.68   -40.44   -20.63
# 3       1/1/2026  00:03:00   -41.12   -41.41   -40.68   -40.44   -20.63
# 4       1/1/2026  00:04:00   -41.12   -41.41   -40.68   -40.44   -20.63
# ...          ...       ...      ...      ...      ...      ...      ...
# 26411  1/19/2026  08:11:00   -41.37   -41.39   -40.73   -40.41   -20.84
# 26412  1/19/2026  08:12:00   -41.37   -41.39   -40.73   -40.41   -20.84
# 26413  1/19/2026  08:13:00   -41.37   -41.39   -40.73   -40.41   -20.84
# 26414  1/19/2026  08:14:00   -41.37   -41.39   -40.73   -40.41   -20.84
# 26415  1/19/2026  08:15:00   -41.37   -41.39   -40.45   -40.42   -20.84
#
#        Point_6  Point_7  Point_8  ...  Point_29  Point_30  Point_31  Point_32  \
# 0         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# 1         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# 2         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# 3         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# 4         4.53     5.00     5.54  ...      5.16      5.26      5.24      5.49
# ...        ...      ...      ...  ...       ...       ...       ...       ...
# 26411     4.51     5.04     5.62  ...      5.09      5.06      4.86      4.76
# 26412     4.51     5.04     5.62  ...      5.09      5.06      4.86      4.76
# 26413     4.51     5.04     5.62  ...      5.09      5.06      4.86      4.76
# 26414     4.51     5.04     5.62  ...      5.09      5.06      4.86      4.76
# 26415     4.51     5.01     5.63  ...      5.09      5.09      5.58      4.77
#
#        Point_33  Point_34  Point_35 Point_36 Point_37  Point_38
# 0        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# 1        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# 2        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# 3        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# 4        -20.29    -39.07      5.00   -39.34     4.84    -41.83
# ...         ...       ...       ...      ...      ...       ...
# 26411    -21.40    -39.07      4.99   -39.79     5.18    -40.04
# 26412    -21.40    -39.07      4.99   -39.79     5.18    -40.04
# 26413    -21.40    -39.07      4.99   -39.79     5.18    -40.04
# 26414    -21.40    -39.07      4.99   -39.79     5.18    -41.04
# 26415    -20.64    -40.14      5.00   -39.08     5.19    -41.64
#
# [26416 rows x 40 columns]

# %%
point_num = []
point_name = []
for i in temp_point_df.loc[:,"Point_Name"]:
    point_num.append(i)
for j in temp_point_df.loc[:,"TechID"]:
    point_name.append(j)

rename_dict = {}
for k in range(0,38):
    rename_dict[point_num[k]] = point_name[k]
rename_dict
# Out:
# {'Point_1': '1W26A',
#  'Point_2': '1W26B',
#  'Point_3': '1W26C',
#  'Point_4': '1W26D',
#  'Point_5': '1W17A',
#  'Point_6': '1W26',
#  'Point_7': '1W27',
#  'Point_8': '1W28',
#  'Point_9': '1W17',
#  'Point_10': '1S17',
#  'Point_11': '1S20',
#  'Point_12': '1P36',
#  'Point_13': '1W09',
#  'Point_14': '1W10',
#  'Point_15': '4L04',
#  'Point_16': '4L11A',
#  'Point_17': '4L26A',
#  'Point_18': '6P24',
#  'Point_19': '6P61',
#  'Point_20': 'ER1',
#  'Point_21': 'ER2',
#  'Point_22': 'ER3',
#  'Point_23': 'ER4',
#  'Point_24': 'ER5',
#  'Point_25': 'ER6',
#  'Point_26': 'CR601001',
#  'Point_27': 'CR601002',
#  'Point_28': 'CR601003',
#  'Point_29': 'CR601005',
#  'Point_30': 'ER12',
#  'Point_31': 'ER13',
#  'Point_32': 'S105A',
#  'Point_33': 'S105B',
#  'Point_34': 'S105C',
#  'Point_35': 'S101A',
#  'Point_36': 'S101B',
#  'Point_37': 'S101C',
#  'Point_38': 'S101D'}

# %%
test_df.rename(columns=rename_dict)
# Out:
#             Date      Time  1W26A  1W26B  1W26C  1W26D  1W17A  1W26  1W27  \
# 0       1/1/2026  00:00:00 -41.12 -41.41 -40.68 -40.44 -20.63  4.53  5.00
# 1       1/1/2026  00:01:00 -41.12 -41.41 -40.68 -40.44 -20.63  4.53  5.00
# 2       1/1/2026  00:02:00 -41.12 -41.41 -40.68 -40.44 -20.63  4.53  5.00
# 3       1/1/2026  00:03:00 -41.12 -41.41 -40.68 -40.44 -20.63  4.53  5.00
# 4       1/1/2026  00:04:00 -41.12 -41.41 -40.68 -40.44 -20.63  4.53  5.00
# ...          ...       ...    ...    ...    ...    ...    ...   ...   ...
# 26411  1/19/2026  08:11:00 -41.37 -41.39 -40.73 -40.41 -20.84  4.51  5.04
# 26412  1/19/2026  08:12:00 -41.37 -41.39 -40.73 -40.41 -20.84  4.51  5.04
# 26413  1/19/2026  08:13:00 -41.37 -41.39 -40.73 -40.41 -20.84  4.51  5.04
# 26414  1/19/2026  08:14:00 -41.37 -41.39 -40.73 -40.41 -20.84  4.51  5.04
# 26415  1/19/2026  08:15:00 -41.37 -41.39 -40.45 -40.42 -20.84  4.51  5.01
#
#        1W28  ...  CR601005  ER12  ER13  S105A   S105B   S105C  S101A   S101B  \
# 0      5.54  ...      5.16  5.26  5.24   5.49  -20.29  -39.07   5.00  -39.34
# 1      5.54  ...      5.16  5.26  5.24   5.49  -20.29  -39.07   5.00  -39.34
# 2      5.54  ...      5.16  5.26  5.24   5.49  -20.29  -39.07   5.00  -39.34
# 3      5.54  ...      5.16  5.26  5.24   5.49  -20.29  -39.07   5.00  -39.34
# 4      5.54  ...      5.16  5.26  5.24   5.49  -20.29  -39.07   5.00  -39.34
# ...     ...  ...       ...   ...   ...    ...     ...     ...    ...     ...
# 26411  5.62  ...      5.09  5.06  4.86   4.76  -21.40  -39.07   4.99  -39.79
# 26412  5.62  ...      5.09  5.06  4.86   4.76  -21.40  -39.07   4.99  -39.79
# 26413  5.62  ...      5.09  5.06  4.86   4.76  -21.40  -39.07   4.99  -39.79
# 26414  5.62  ...      5.09  5.06  4.86   4.76  -21.40  -39.07   4.99  -39.79
# 26415  5.63  ...      5.09  5.09  5.58   4.77  -20.64  -40.14   5.00  -39.08
#
#       S101C   S101D
# 0      4.84  -41.83
# 1      4.84  -41.83
# 2      4.84  -41.83
# 3      4.84  -41.83
# 4      4.84  -41.83
# ...     ...     ...
# 26411  5.18  -40.04
# 26412  5.18  -40.04
# 26413  5.18  -40.04
# 26414  5.18  -41.04
# 26415  5.19  -41.64
#
# [26416 rows x 40 columns]

# %%
import csv
import pandas as pd

path = '/home/engineering/Documents/PdM/data/test.txt'
path1 = '/home/engineering/Documents/PdM/data/amp_press_data/point_names.csv'

try:
    with open(path, 'r', newline='') as f:
        sample = f.read(2048)
        dialect = csv.Sniffer().sniff(sample)
    if dialect.delimiter == ',':
        data = pd.read_csv(path, low_memory=False)
        df_data = pd.DataFrame(data)
    else:
        raise csv.Error
    
except csv.Error:
    print('try not successful')
# Out:
# try not successful

# %%
import utilities

# %%
path1 = '/home/engineering/Documents/PdM/data/amp_press_data/raw/refrigerant_monitoring_2026_01_19.csv'
path2 = '/home/engineering/Documents/PdM/data/amp_press_data/raw/refrigerant_monitoring_2026_01_28.csv'

# %%
df1 = utilities.import_csvfile(path1)
df2 = utilities.import_csvfile(path2)

# %%
df1.head(10)
# Out:
#      <>Date      Time Point_1 Point_2 Point_3 Point_4  Point_5 Point_6  \
# 0  1/1/2026  00:00:00    0.04     161   28.34     267   -40.66    0.34
# 1  1/1/2026  00:01:00    0.04     161   28.34     267   -40.66    0.34
# 2  1/1/2026  00:02:00    0.04     161   28.34     267   -40.66    0.34
# 3  1/1/2026  00:03:00    0.04     161   28.34     267   -40.66    0.34
# 4  1/1/2026  00:04:00    0.04     161   28.34     267   -40.66    0.34
# 5  1/1/2026  00:05:00    0.04     159   28.34     267   -40.66    0.34
# 6  1/1/2026  00:06:00    0.04     159   28.34     267   -40.66    0.34
# 7  1/1/2026  00:07:00    0.04     159   28.34     269   -40.66    0.34
# 8  1/1/2026  00:08:00    0.04     159   28.34     269   -40.66    0.34
# 9  1/1/2026  00:09:00    0.04     159   28.34     269   -40.66    0.34
#
#   Point_7 Point_8  ... Point_10 Point_11 Point_12 Point_13 Point_14 Point_15  \
# 0     165   12.84  ...     5.24    14.96      237     0.04     5.43      173
# 1     165   12.88  ...     5.24    14.96      240     0.04     5.43      173
# 2     165   11.85  ...     5.24    14.96      231     0.04     5.43      173
# 3     165   12.87  ...     5.24    14.96      231     0.04     5.43      173
# 4     165   13.73  ...     5.24    14.96      237     0.04     5.43      173
# 5     165   13.73  ...     5.24    14.96      234     0.04     5.43      173
# 6     165   13.73  ...     5.24    14.96      235     0.04     5.43      173
# 7     165   13.73  ...     5.24    14.96      235     0.04     5.43      173
# 8     165   14.74  ...     5.24    14.96      235     0.04     5.43      173
# 9     165   14.74  ...     5.24    14.96      240     0.04     5.43      173
#
#   Point_16 Point_17 Point_18 Point_19
# 0     0.09   115.53     0.09   115.31
# 1     0.09      113     0.09   112.78
# 2     0.09      113     0.09   112.78
# 3     0.09   110.44     0.09   110.25
# 4     0.09   110.44     0.09   110.25
# 5     0.09   110.44     0.09   107.69
# 6     0.09   110.44     0.09   107.69
# 7     0.09   110.44     7.23   200.34
# 8     0.09   110.44     7.75   211.78
# 9     0.09   107.94     7.75   211.78
#
# [10 rows x 21 columns]
